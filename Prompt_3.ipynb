# %% [markdown]
# <a href="https://colab.research.google.com/github/Colanimmy/AAI2025-DEVIN-COPY/blob/2026fall/Prompt_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Prompt 1

#Summarize Destiny 2 for someone who has never played the game.

#Write one paragraph.
#Keep the summary under 100 words.
#Explain the main purpose of the game.
#Mention important activities and equipment.
#Use clear language appropriate for a beginner.

# %%
#OUTPUT

#Destiny 2 is an online sci-fi action game where you play as a Guardian, a powerful protector of humanity. The main purpose is to fight enemies, complete missions, and become stronger by earning better equipment. Players can explore different planets, follow story campaigns, complete strikes and raids with teammates, or compete against other players in the Crucible. Guardians use many types of weapons, armor, and special abilities that can be customized to fit different playstyles. The game focuses on combat, teamwork, exploration, and collecting powerful gear.

# %%
#Prompt 2

#Review the original summary you created and critique it using the following criteria: Clarity — Is it easy for someone unfamiliar with Destiny 2 to understand?

#Audience — Is the language appropriate for a beginner?
#Relevance — Does it focus on the most important information?
#Length — Is it under 100 words?
#Formatting — Is it presented as one paragraph?
#Completeness — Does it explain the main purpose of the game and mention important activities and equipment?

#First, identify specific strengths and weaknesses in the original summary.

#Then rewrite the summary to correct any weaknesses you identified.

#Return your response using this format:

#SELF-CRITIQUE:
#<critique>

#IMPROVED SUMMARY:
#<revised summary>

# %%
#OUTPUT 2

#SELF-CRITIQUE:
#The original summary is clear and easy for someone unfamiliar with Destiny 2 to understand. The language is beginner-friendly and avoids complicated game terminology without explanation. It stays relevant by focusing on the player's role, the main goal, major activities, and equipment. It is also under 100 words and presented as one paragraph. For completeness, it successfully mentions missions, strikes, raids, the Crucible, weapons, armor, and abilities. One weakness is that phrases such as “strikes,” “raids,” and “Crucible” may still be unfamiliar to beginners. These activities could be described more plainly.

#IMPROVED SUMMARY:
#Destiny 2 is an online sci-fi action game where you play as a Guardian, a powerful defender of humanity. The main goal is to fight enemies, complete missions, and become stronger by collecting better gear. You can explore different worlds, play story missions, team up with other players for cooperative challenges such as strikes and raids, or compete against players in the Crucible. Guardians use different weapons, armor, and special abilities that can be customized for different playstyles. The game focuses on combat, teamwork, exploration, and collecting powerful equipment.
